# %%
from PIL import Image
from IPython.display import display

# %% [markdown]
# ## Train

# %%
# %cd C:/Users/user/PycharmProjects/object-detection-yolov5/yolov5/test-project/izolator/validation/exp5
F1_curve = Image.open("F1_curve.png");
P_curve = Image.open("P_curve.png");
PR_curve = Image.open("PR_curve.png");
R_curve = Image.open("R_curve.png");
display(F1_curve, P_curve, PR_curve, R_curve)
# Out:
# C:\Users\user\PycharmProjects\object-detection-yolov5\yolov5\test-project\izolator\validation\exp5
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>

# %% [markdown]
# ## Val

# %%
# %cd C:/Users/user/PycharmProjects/object-detection-yolov5/yolov5/test-project/izolator/validation/exp6
F1_curve = Image.open("F1_curve.png");
P_curve = Image.open("P_curve.png");
PR_curve = Image.open("PR_curve.png");
R_curve = Image.open("R_curve.png");
display(F1_curve, P_curve, PR_curve, R_curve)
# Out:
# C:\Users\user\PycharmProjects\object-detection-yolov5\yolov5\test-project\izolator\validation\exp6
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2250x1500>
